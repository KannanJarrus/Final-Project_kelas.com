# %%
# general functions
import os
import cv2
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from collections import OrderedDict
# visualization
from PIL import Image
# identifying faces
#%pip install mtcnn
from mtcnn.mtcnn import MTCNN
# visualizing bounding boxes
import matplotlib.patches as patches
# CNN
import keras
from sklearn.model_selection import train_test_split
# Moving files between directories
import shutil
from shutil import unpack_archive
from subprocess import check_output

# %%
lfw_allnames = pd.read_csv("lfw_allnames.csv")

# %%
matchpairsDevTest = pd.read_csv("matchpairsDevTest.csv")
matchpairsDevTrain = pd.read_csv("matchpairsDevTrain.csv")
mismatchpairsDevTest = pd.read_csv("mismatchpairsDevTest.csv")
mismatchpairsDevTrain = pd.read_csv("mismatchpairsDevTrain.csv")
pairs = pd.read_csv("pairs.csv")

# %%
pairs = pairs.rename(columns={'name': 'name1', 'Unnamed: 3': 'name2'})
matched_pairs = pairs[pairs["name2"].isnull()].drop("name2", axis=1)
mismatched_pairs = pairs[pairs["name2"].notnull()]
people = pd.read_csv("people.csv")

# %%
people = people[people.name.notnull()]
peopleDevTest = pd.read_csv("peopleDevTest.csv")
peopleDevTrain = pd.read_csv("peopleDevTrain.csv")

# %%
lfw_allnames.head()
# Out:
#               name  images
# 0          AJ_Cook       1
# 1         AJ_Lamas       1
# 2    Aaron_Eckhart       1
# 3      Aaron_Guiel       1
# 4  Aaron_Patterson       1

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
print("Summary:")
print("There are " + 
      str(lfw_allnames.shape[0]) + 
      " unique celebrities in the entire dataset, of whom " + 
      str(sum(lfw_allnames.images > 1)) + 
      " are represented by multiple images. The entire number of images available is " + 
      str(sum(lfw_allnames.images)) + 
      ". The most represented celebrity is " + 
      str(lfw_allnames.iloc[lfw_allnames['images'].idxmax()][0]) + 
      ", with " + 
      str(max(lfw_allnames.images)) + 
      " unique images in the dataset.")
# Out:
# Summary:
# There are 5749 unique celebrities in the entire dataset, of whom 1680 are represented by multiple images. The entire number of images available is 13233. The most represented celebrity is George_W_Bush, with 530 unique images in the dataset.
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_11308\170007965.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   str(lfw_allnames.iloc[lfw_allnames['images'].idxmax()][0]) +

# %%
# shape data frame so there is a row per image, matched to relevant jpg file
image_paths = lfw_allnames.loc[lfw_allnames.index.repeat(lfw_allnames['images'])]
image_paths['image_path'] = 1 + image_paths.groupby('name').cumcount()
image_paths['image_path'] = image_paths.image_path.apply(lambda x: '{0:0>4}'.format(x))
image_paths['image_path'] = image_paths.name + "/" + image_paths.name + "_" + image_paths.image_path + ".jpg"
image_paths = image_paths.drop("images", axis=1)  # Fixed drop

# Ensure reproducibility by setting a random seed
lfw_train, lfw_test = train_test_split(image_paths, test_size=0.2, random_state=42)

# Reset index and drop it
lfw_train = lfw_train.reset_index().drop("index", axis=1)
lfw_test = lfw_test.reset_index().drop("index", axis=1)

# Verify overlap and mismatch
print(len(set(lfw_train.name).intersection(set(lfw_test.name))))  # Should be 843
print(len(set(lfw_test.name) - set(lfw_train.name)))  # Should be 874
# Out:
# 852
# 863

# %%
# Assuming image_paths.image_path contains the relative paths
widths = []
heights = []
files = image_paths.image_path

# Loop through image paths and extract width and height
for file in files:
    path = "lfw-deepfunneled/" + str(file)  # Relative path if working in the same folder
    im = Image.open(path)
    widths.append(im.width)
    heights.append(im.height)

# Creating a DataFrame and summarizing the image dimensions
pd.DataFrame({'height': heights, 'width': widths}).describe()
# Out:
#         height    width
# count  13233.0  13233.0
# mean     250.0    250.0
# std        0.0      0.0
# min      250.0    250.0
# 25%      250.0    250.0
# 50%      250.0    250.0
# 75%      250.0    250.0
# max      250.0    250.0

# %%
image_paths['name'].value_counts()[:10].plot(kind = "bar")
plt.show()

# %%
ind_counts = image_paths.groupby('name').count().image_path
print(str(sum(ind_counts[ind_counts==1])) + " individuals, which is " + str(round(100*(sum(ind_counts[ind_counts==1])/sum(ind_counts)))) + "% of the total individuals considered, are only represented by a single image in this dataset.")
# Out:
# 4069 individuals, which is 31% of the total individuals considered, are only represented by a single image in this dataset.

# %%
im = Image.open("lfw-deepfunneled/" + str(lfw_train.image_path[0]))  # Use relative path
plt.imshow(im)
plt.show()

# %%
from mtcnn import MTCNN
import cv2
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import os

# Assuming the images are inside a folder like "./lfw-deepfunneled/"
image_folder = "./lfw-deepfunneled/"
image_path = os.path.join(image_folder, str(lfw_train.image_path[0]))
image_bgr = cv2.imread(image_path)

if image_bgr is None:
    raise ValueError(f"Image not found at path: {image_path}")

# Convert BGR to RGB for MTCNN
image = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

# Run MTCNN detection
detector = MTCNN()
result = detector.detect_faces(image)

if not result:
    raise ValueError("No face detected in the image.")

# Get bounding box and keypoints
bounding_box = result[0]['box']
keypoints = result[0]['keypoints']

# Plot
fig, ax = plt.subplots(1)
ax.imshow(image)

# Draw bounding box
rect = patches.Rectangle(
    (bounding_box[0], bounding_box[1]),
    bounding_box[2], bounding_box[3],
    linewidth=2, edgecolor='r', facecolor='none'
)
ax.add_patch(rect)

# Draw keypoints
for key in keypoints:
    x, y = keypoints[key]
    kp = patches.Circle((x, y), radius=2, linewidth=2, edgecolor='b', facecolor='blue')
    ax.add_patch(kp)

plt.axis('off')
plt.show()

# %%
from mtcnn import MTCNN
import cv2
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import os

# Assuming image_folder is defined and lfw_train.image_path[0] gives a valid relative path
image_path = os.path.join(image_folder, str(lfw_train.image_path[0]))

# Load and prepare image
image_bgr = cv2.imread(image_path)
if image_bgr is None:
    raise ValueError(f"Image not found at path: {image_path}")
image = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

# Detect faces
detector = MTCNN()
results = detector.detect_faces(image)

if not results:
    raise ValueError("No faces detected.")

# Select the largest face (most likely the main one)
def area(face):
    x, y, w, h = face['box']
    return w * h

largest_face = max(results, key=area)
bounding_box = largest_face['box']
keypoints = largest_face['keypoints']

# Plot
fig, ax = plt.subplots(1)
ax.imshow(image)

# Draw bounding box
rect = patches.Rectangle(
    (bounding_box[0], bounding_box[1]),
    bounding_box[2], bounding_box[3],
    linewidth=2, edgecolor='r', facecolor='none'
)
ax.add_patch(rect)

# Draw facial keypoints
for key in keypoints:
    x, y = keypoints[key]
    kp = patches.Circle((x, y), radius=4, linewidth=1, edgecolor='cyan', facecolor='cyan')
    ax.add_patch(kp)

# %%
not_george = image_paths[image_paths.name!="George_W_Bush"].sample(530)
not_george.name = "not_George"
GWB_data = pd.concat([image_paths[image_paths.name=="George_W_Bush"],
                     not_george])

# %%
# withhold final test data
bush_train, bush_test = train_test_split(GWB_data, test_size=0.2)
#  It is also useful to reserve a validation set in the training data, for use in the model construction
bush_train, bush_val = train_test_split(bush_train,test_size=0.2)

# %%
# initialize sequential network
from keras.models import Sequential
# include convolutional layers
from keras.layers import Conv2D
# Pooling layers
from keras.layers import MaxPooling2D
# flatten layers into single vector
from keras.layers import Flatten
from keras.layers import Dense

# %%
import os
import shutil

def directory_mover(data, dir_name):
    co = 0
    base_src = os.path.join('lfw-deepfunneled')
    base_dst = os.path.join('working', dir_name)

    for image in data.image_path:
        # get the category (person's name)
        data_type = data[data['image_path'] == image]['name']
        data_type = str(list(data_type)[0])

        # create destination directories if they don't exist
        dst_dir = os.path.join(base_dst, data_type)
        os.makedirs(dst_dir, exist_ok=True)

        path_from = os.path.join(base_src, image)
        path_to = os.path.join(dst_dir)

        try:
            shutil.copy(path_from, path_to)
            co += 1
        except FileNotFoundError:
            print(f"⚠️ File not found: {path_from}")

    print(f'Moved {co} images to {dir_name} folder.')

# %%
directory_mover(bush_train,"Bush_train/")
directory_mover(bush_val,"Bush_val/")
directory_mover(bush_test,"Bush_test/")
# Out:
# Moved 678 images to Bush_train/ folder.
# Moved 170 images to Bush_val/ folder.
# Moved 212 images to Bush_test/ folder.

# %%
from tensorflow import keras

train_datagen = keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

test_datagen = keras.preprocessing.image.ImageDataGenerator(rescale=1./255)

Bush_training_set = train_datagen.flow_from_directory(
    'working/Bush_train/',
    target_size=(250, 250),
    batch_size=32,
    class_mode='binary'
)

Bush_val_set = test_datagen.flow_from_directory(
    'working/Bush_val/',
    target_size=(250, 250),
    batch_size=32,
    class_mode='binary'
)

Bush_test_set = test_datagen.flow_from_directory(
    'working/Bush_test/',
    target_size=(250, 250),
    batch_size=32,
    class_mode='binary'
)
# Out:
# Found 1135 images belonging to 2 classes.
# Found 326 images belonging to 2 classes.
# Found 399 images belonging to 2 classes.

# %%
from keras.layers import Conv2D,MaxPooling2D,Dense,Flatten,Dropout
from tensorflow.keras.optimizers import Adam
from keras.callbacks import TensorBoard
cnn_model = Sequential([
    Conv2D(filters=32,kernel_size=3,activation='relu',input_shape = (250, 250, 3)),
    MaxPooling2D(pool_size=2) ,# down sampling the output instead of 28*28 it is 14*14
    Dropout(0.2),
    Flatten(), # flatten out the layers
    Dense(32,activation='relu'),
    Dense(10,activation = 'softmax')
    
])
# Out:
# C:\Users\ASUS\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
from tensorflow.keras.optimizers import Adam

optimizer = Adam(learning_rate=0.001)
cnn_model.compile(loss='sparse_categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# %%
history = cnn_model.fit(
    Bush_training_set,
    batch_size=4096,
    epochs=75,
    verbose=1,
    validation_data=Bush_val_set
)
# Out:
# C:\Users\ASUS\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 53s 1s/step - accuracy: 0.4824 - loss: 6.7894 - val_accuracy: 0.6472 - val_loss: 0.7507
# Epoch 2/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.6730 - loss: 0.6395 - val_accuracy: 0.5613 - val_loss: 0.8195
# Epoch 3/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.6531 - loss: 0.6253 - val_accuracy: 0.6840 - val_loss: 0.6082
# Epoch 4/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 47s 1s/step - accuracy: 0.7867 - loss: 0.4909 - val_accuracy: 0.7178 - val_loss: 0.5527
# Epoch 5/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 31s 869ms/step - accuracy: 0.7808 - loss: 0.4684 - val_accuracy: 0.7393 - val_loss: 0.5000
# Epoch 6/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 36s 988ms/step - accuracy: 0.8116 - loss: 0.4047 - val_accuracy: 0.7515 - val_loss: 0.4742
# Epoch 7/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.8113 - loss: 0.4179 - val_accuracy: 0.8252 - val_loss: 0.3876
# Epoch 8/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 34s 937ms/step - accuracy: 0.8617 - loss: 0.3335 - val_accuracy: 0.8436 - val_loss: 0.3442
# Epoch 9/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - accuracy: 0.8616 - loss: 0.3192 - val_accuracy: 0.8528 - val_loss: 0.3783
# Epoch 10/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 31s 858ms/step - accuracy: 0.8595 - loss: 0.3266 - val_accuracy: 0.8926 - val_loss: 0.2777
# Epoch 11/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 30s 838ms/step - accuracy: 0.8846 - loss: 0.2899 - val_accuracy: 0.8865 - val_loss: 0.2714
# Epoch 12/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 34s 932ms/step - accuracy: 0.9114 - loss: 0.2278 - val_accuracy: 0.8926 - val_loss: 0.2512
# Epoch 13/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 31s 853ms/step - accuracy: 0.9098 - loss: 0.2331 - val_accuracy: 0.9080 - val_loss: 0.2358
# Epoch 14/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 30s 834ms/step - accuracy: 0.8868 - loss: 0.2685 - val_accuracy: 0.8896 - val_loss: 0.2882
# Epoch 15/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 30s 832ms/step - accuracy: 0.9181 - loss: 0.2102 - val_accuracy: 0.8957 - val_loss: 0.2343
# Epoch 16/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 30s 839ms/step - accuracy: 0.9277 - loss: 0.1890 - val_accuracy: 0.8589 - val_loss: 0.3535
# Epoch 17/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 33s 924ms/step - accuracy: 0.8921 - loss: 0.2774 - val_accuracy: 0.8896 - val_loss: 0.2554
# Epoch 18/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 36s 995ms/step - accuracy: 0.9122 - loss: 0.2283 - val_accuracy: 0.9233 - val_loss: 0.2061
# Epoch 19/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 34s 936ms/step - accuracy: 0.9175 - loss: 0.1916 - val_accuracy: 0.9172 - val_loss: 0.1943
# Epoch 20/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 33s 931ms/step - accuracy: 0.9215 - loss: 0.1826 - val_accuracy: 0.9141 - val_loss: 0.1852
# Epoch 21/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 31s 847ms/step - accuracy: 0.9483 - loss: 0.1433 - val_accuracy: 0.9049 - val_loss: 0.1994
# Epoch 22/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 34s 933ms/step - accuracy: 0.9435 - loss: 0.1663 - val_accuracy: 0.9202 - val_loss: 0.1992
# Epoch 23/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 31s 851ms/step - accuracy: 0.9458 - loss: 0.1511 - val_accuracy: 0.9141 - val_loss: 0.2257
# Epoch 24/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 33s 914ms/step - accuracy: 0.9435 - loss: 0.1565 - val_accuracy: 0.9325 - val_loss: 0.1692
# Epoch 25/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.9426 - loss: 0.1388 - val_accuracy: 0.9540 - val_loss: 0.1429
# Epoch 26/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 34s 943ms/step - accuracy: 0.9342 - loss: 0.1527 - val_accuracy: 0.8865 - val_loss: 0.2766
# Epoch 27/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 33s 911ms/step - accuracy: 0.9368 - loss: 0.1616 - val_accuracy: 0.9448 - val_loss: 0.1729
# Epoch 28/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - accuracy: 0.9581 - loss: 0.1324 - val_accuracy: 0.9601 - val_loss: 0.1388
# Epoch 29/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - accuracy: 0.9445 - loss: 0.1483 - val_accuracy: 0.9202 - val_loss: 0.2246
# Epoch 30/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 35s 966ms/step - accuracy: 0.9449 - loss: 0.1536 - val_accuracy: 0.9294 - val_loss: 0.1736
# Epoch 31/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 35s 973ms/step - accuracy: 0.9559 - loss: 0.1258 - val_accuracy: 0.9417 - val_loss: 0.1558
# Epoch 32/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 34s 952ms/step - accuracy: 0.9452 - loss: 0.1341 - val_accuracy: 0.9509 - val_loss: 0.1361
# Epoch 33/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 27s 754ms/step - accuracy: 0.9712 - loss: 0.1008 - val_accuracy: 0.9356 - val_loss: 0.1748
# Epoch 34/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 724ms/step - accuracy: 0.9496 - loss: 0.1236 - val_accuracy: 0.9417 - val_loss: 0.1710
# Epoch 35/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 28s 786ms/step - accuracy: 0.9589 - loss: 0.1076 - val_accuracy: 0.9448 - val_loss: 0.1536
# Epoch 36/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 28s 771ms/step - accuracy: 0.9591 - loss: 0.1228 - val_accuracy: 0.9540 - val_loss: 0.1348
# Epoch 37/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 27s 745ms/step - accuracy: 0.9692 - loss: 0.0855 - val_accuracy: 0.9325 - val_loss: 0.1827
# Epoch 38/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 719ms/step - accuracy: 0.9645 - loss: 0.1042 - val_accuracy: 0.9417 - val_loss: 0.1527
# Epoch 39/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 27s 746ms/step - accuracy: 0.9623 - loss: 0.1119 - val_accuracy: 0.9417 - val_loss: 0.1616
# Epoch 40/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 728ms/step - accuracy: 0.9632 - loss: 0.1060 - val_accuracy: 0.9509 - val_loss: 0.1213
# Epoch 41/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 730ms/step - accuracy: 0.9719 - loss: 0.0943 - val_accuracy: 0.9294 - val_loss: 0.1599
# Epoch 42/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 28s 769ms/step - accuracy: 0.9663 - loss: 0.0855 - val_accuracy: 0.9479 - val_loss: 0.1163
# Epoch 43/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 28s 761ms/step - accuracy: 0.9757 - loss: 0.0853 - val_accuracy: 0.9417 - val_loss: 0.1504
# Epoch 44/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 715ms/step - accuracy: 0.9513 - loss: 0.1301 - val_accuracy: 0.9479 - val_loss: 0.1625
# Epoch 45/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 27s 750ms/step - accuracy: 0.9649 - loss: 0.1103 - val_accuracy: 0.9540 - val_loss: 0.1277
# Epoch 46/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 27s 733ms/step - accuracy: 0.9633 - loss: 0.0807 - val_accuracy: 0.9509 - val_loss: 0.1325
# Epoch 47/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 27s 735ms/step - accuracy: 0.9710 - loss: 0.0803 - val_accuracy: 0.9540 - val_loss: 0.1301
# Epoch 48/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 731ms/step - accuracy: 0.9730 - loss: 0.0799 - val_accuracy: 0.9540 - val_loss: 0.1447
# Epoch 49/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 27s 734ms/step - accuracy: 0.9638 - loss: 0.1049 - val_accuracy: 0.9540 - val_loss: 0.1819
# Epoch 50/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 724ms/step - accuracy: 0.9813 - loss: 0.0632 - val_accuracy: 0.9018 - val_loss: 0.2681
# Epoch 51/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 27s 735ms/step - accuracy: 0.9702 - loss: 0.0729 - val_accuracy: 0.9356 - val_loss: 0.2315
# Epoch 52/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 27s 754ms/step - accuracy: 0.9692 - loss: 0.0819 - val_accuracy: 0.9540 - val_loss: 0.1380
# Epoch 53/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 27s 734ms/step - accuracy: 0.9818 - loss: 0.0697 - val_accuracy: 0.9448 - val_loss: 0.1689
# Epoch 54/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 715ms/step - accuracy: 0.9570 - loss: 0.1072 - val_accuracy: 0.9141 - val_loss: 0.3090
# Epoch 55/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 27s 737ms/step - accuracy: 0.9662 - loss: 0.0936 - val_accuracy: 0.9540 - val_loss: 0.1519
# Epoch 56/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 727ms/step - accuracy: 0.9583 - loss: 0.1131 - val_accuracy: 0.9540 - val_loss: 0.1334
# Epoch 57/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 726ms/step - accuracy: 0.9641 - loss: 0.0961 - val_accuracy: 0.9417 - val_loss: 0.1483
# Epoch 58/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 27s 746ms/step - accuracy: 0.9709 - loss: 0.0987 - val_accuracy: 0.9417 - val_loss: 0.1572
# Epoch 59/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 27s 732ms/step - accuracy: 0.9677 - loss: 0.0994 - val_accuracy: 0.9356 - val_loss: 0.1959
# Epoch 60/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 710ms/step - accuracy: 0.9813 - loss: 0.0675 - val_accuracy: 0.9387 - val_loss: 0.1518
# Epoch 61/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 27s 741ms/step - accuracy: 0.9590 - loss: 0.1012 - val_accuracy: 0.9571 - val_loss: 0.1390
# Epoch 62/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 721ms/step - accuracy: 0.9764 - loss: 0.0772 - val_accuracy: 0.9264 - val_loss: 0.2106
# Epoch 63/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 718ms/step - accuracy: 0.9534 - loss: 0.1302 - val_accuracy: 0.9571 - val_loss: 0.1192
# Epoch 64/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 27s 739ms/step - accuracy: 0.9722 - loss: 0.1031 - val_accuracy: 0.9479 - val_loss: 0.1537
# Epoch 65/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 27s 740ms/step - accuracy: 0.9690 - loss: 0.0818 - val_accuracy: 0.9601 - val_loss: 0.1415
# Epoch 66/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 709ms/step - accuracy: 0.9797 - loss: 0.0683 - val_accuracy: 0.9540 - val_loss: 0.1498
# Epoch 67/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 27s 739ms/step - accuracy: 0.9814 - loss: 0.0561 - val_accuracy: 0.9417 - val_loss: 0.1872
# Epoch 68/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 27s 727ms/step - accuracy: 0.9723 - loss: 0.0619 - val_accuracy: 0.9663 - val_loss: 0.1254
# Epoch 69/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 720ms/step - accuracy: 0.9789 - loss: 0.0616 - val_accuracy: 0.9479 - val_loss: 0.1751
# Epoch 70/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 731ms/step - accuracy: 0.9635 - loss: 0.0908 - val_accuracy: 0.9540 - val_loss: 0.1391
# Epoch 71/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 27s 756ms/step - accuracy: 0.9797 - loss: 0.0545 - val_accuracy: 0.9601 - val_loss: 0.1351
# Epoch 72/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 27s 734ms/step - accuracy: 0.9752 - loss: 0.0596 - val_accuracy: 0.9663 - val_loss: 0.1566
# Epoch 73/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 26s 724ms/step - accuracy: 0.9701 - loss: 0.1146 - val_accuracy: 0.9663 - val_loss: 0.1358
# Epoch 74/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 27s 733ms/step - accuracy: 0.9897 - loss: 0.0485 - val_accuracy: 0.9632 - val_loss: 0.1139
# Epoch 75/75
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 27s 738ms/step - accuracy: 0.9897 - loss: 0.0374 - val_accuracy: 0.9540 - val_loss: 0.1468

# %%
plt.figure(figsize=(10, 10))

plt.subplot(2, 2, 1)
plt.plot(history.history['loss'], label='Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title('Training - Loss Function')

plt.subplot(2, 2, 2)
plt.plot(history.history['accuracy'], label='Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.title('Train - Accuracy')
plt.show()

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
from keras.preprocessing import image

# create a function to predict class of images in a directory, given a trained classifier
def predictions(dir_name,classifier,binary):
    # dir_name should include name of predicted invididual - could edit this to iterate through folders in future
    predictions = []
    for im in os.listdir(dir_name):
        test_image = image.load_img(dir_name + str(im), target_size = (250,250))
        test_image = image.img_to_array(test_image)
        test_image = np.expand_dims(test_image, axis = 0)
        if(binary is True):
            result = float(str(classifier.predict(test_image))[2])
        else: 
            result = np.argmax(classifier.predict(test_image))
        predictions.append(result)
    return(predictions)

# %%
Bush_test_names = []
# collect all file names
for i in range(len(Bush_test_set.filenames)):
    Bush_test_names.append(Bush_test_set.filenames[i])
# extract unique names, in order
for i in range(len(Bush_test_names)):
    Bush_test_names[i] = Bush_test_names[i].split("/")[0]
Bush_test_name_order = list(OrderedDict.fromkeys(Bush_test_names))

# %%
Bush_test_name_order
# Out:
# ['George_W_Bush\\George_W_Bush_0001.jpg',
#  'George_W_Bush\\George_W_Bush_0003.jpg',
#  'George_W_Bush\\George_W_Bush_0008.jpg',
#  'George_W_Bush\\George_W_Bush_0009.jpg',
#  'George_W_Bush\\George_W_Bush_0011.jpg',
#  'George_W_Bush\\George_W_Bush_0013.jpg',
#  'George_W_Bush\\George_W_Bush_0014.jpg',
#  'George_W_Bush\\George_W_Bush_0015.jpg',
#  'George_W_Bush\\George_W_Bush_0021.jpg',
#  'George_W_Bush\\George_W_Bush_0022.jpg',
#  'George_W_Bush\\George_W_Bush_0023.jpg',
#  'George_W_Bush\\George_W_Bush_0026.jpg',
#  'George_W_Bush\\George_W_Bush_0027.jpg',
#  'George_W_Bush\\George_W_Bush_0036.jpg',
#  'George_W_Bush\\George_W_Bush_0041.jpg',
#  'George_W_Bush\\George_W_Bush_0042.jpg',
#  'George_W_Bush\\George_W_Bush_0044.jpg',
#  'George_W_Bush\\George_W_Bush_0045.jpg',
#  'George_W_Bush\\George_W_Bush_0047.jpg',
#  'George_W_Bush\\George_W_Bush_0050.jpg',
#  'George_W_Bush\\George_W_Bush_0053.jpg',
#  'George_W_Bush\\George_W_Bush_0057.jpg',
#  'George_W_Bush\\George_W_Bush_0060.jpg',
#  'George_W_Bush\\George_W_Bush_0061.jpg',
#  'George_W_Bush\\George_W_Bush_0063.jpg',
#  'George_W_Bush\\George_W_Bush_0068.jpg',
#  'George_W_Bush\\George_W_Bush_0069.jpg',
#  'George_W_Bush\\George_W_Bush_0071.jpg',
#  'George_W_Bush\\George_W_Bush_0072.jpg',
#  'George_W_Bush\\George_W_Bush_0077.jpg',
#  'George_W_Bush\\George_W_Bush_0082.jpg',
#  'George_W_Bush\\George_W_Bush_0089.jpg',
#  'George_W_Bush\\George_W_Bush_0090.jpg',
#  'George_W_Bush\\George_W_Bush_0091.jpg',
#  'George_W_Bush\\George_W_Bush_0093.jpg',
#  'George_W_Bush\\George_W_Bush_0099.jpg',
#  'George_W_Bush\\George_W_Bush_0101.jpg',
#  'George_W_Bush\\George_W_Bush_0105.jpg',
#  'George_W_Bush\\George_W_Bush_0108.jpg',
#  'George_W_Bush\\George_W_Bush_0109.jpg',
#  'George_W_Bush\\George_W_Bush_0110.jpg',
#  'George_W_Bush\\George_W_Bush_0113.jpg',
#  'George_W_Bush\\George_W_Bush_0114.jpg',
#  'George_W_Bush\\George_W_Bush_0115.jpg',
#  'George_W_Bush\\George_W_Bush_0121.jpg',
#  'George_W_Bush\\George_W_Bush_0127.jpg',
#  'George_W_Bush\\George_W_Bush_0129.jpg',
#  'George_W_Bush\\George_W_Bush_0135.jpg',
#  'George_W_Bush\\George_W_Bush_0138.jpg',
#  'George_W_Bush\\George_W_Bush_0139.jpg',
#  'George_W_Bush\\George_W_Bush_0141.jpg',
#  'George_W_Bush\\George_W_Bush_0144.jpg',
#  'George_W_Bush\\George_W_Bush_0147.jpg',
#  'George_W_Bush\\George_W_Bush_0155.jpg',
#  'George_W_Bush\\George_W_Bush_0156.jpg',
#  'George_W_Bush\\George_W_Bush_0159.jpg',
#  'George_W_Bush\\George_W_Bush_0160.jpg',
#  'George_W_Bush\\George_W_Bush_0166.jpg',
#  'George_W_Bush\\George_W_Bush_0168.jpg',
#  'George_W_Bush\\George_W_Bush_0170.jpg',
#  'George_W_Bush\\George_W_Bush_0171.jpg',
#  'George_W_Bush\\George_W_Bush_0172.jpg',
#  'George_W_Bush\\George_W_Bush_0175.jpg',
#  'George_W_Bush\\George_W_Bush_0177.jpg',
#  'George_W_Bush\\George_W_Bush_0181.jpg',
#  'George_W_Bush\\George_W_Bush_0183.jpg',
#  'George_W_Bush\\George_W_Bush_0184.jpg',
#  'George_W_Bush\\George_W_Bush_0187.jpg',
#  'George_W_Bush\\George_W_Bush_0188.jpg',
#  'George_W_Bush\\George_W_Bush_0193.jpg',
#  'George_W_Bush\\George_W_Bush_0196.jpg',
#  'George_W_Bush\\George_W_Bush_0201.jpg',
#  'George_W_Bush\\George_W_Bush_0203.jpg',
#  'George_W_Bush\\George_W_Bush_0205.jpg',
#  'George_W_Bush\\George_W_Bush_0206.jpg',
#  'George_W_Bush\\George_W_Bush_0213.jpg',
#  'George_W_Bush\\George_W_Bush_0214.jpg',
#  'George_W_Bush\\George_W_Bush_0216.jpg',
#  'George_W_Bush\\George_W_Bush_0218.jpg',
#  'George_W_Bush\\George_W_Bush_0219.jpg',
#  'George_W_Bush\\George_W_Bush_0224.jpg',
#  'George_W_Bush\\George_W_Bush_0225.jpg',
#  'George_W_Bush\\George_W_Bush_0227.jpg',
#  'George_W_Bush\\George_W_Bush_0230.jpg',
#  'George_W_Bush\\George_W_Bush_0234.jpg',
#  'George_W_Bush\\George_W_Bush_0236.jpg',
#  'George_W_Bush\\George_W_Bush_0238.jpg',
#  'George_W_Bush\\George_W_Bush_0239.jpg',
#  'George_W_Bush\\George_W_Bush_0240.jpg',
#  'George_W_Bush\\George_W_Bush_0245.jpg',
#  'George_W_Bush\\George_W_Bush_0246.jpg',
#  'George_W_Bush\\George_W_Bush_0250.jpg',
#  'George_W_Bush\\George_W_Bush_0252.jpg',
#  'George_W_Bush\\George_W_Bush_0256.jpg',
#  'George_W_Bush\\George_W_Bush_0263.jpg',
#  'George_W_Bush\\George_W_Bush_0264.jpg',
#  'George_W_Bush\\George_W_Bush_0265.jpg',
#  'George_W_Bush\\George_W_Bush_0272.jpg',
#  'George_W_Bush\\George_W_Bush_0273.jpg',
#  'George_W_Bush\\George_W_Bush_0274.jpg',
#  'George_W_Bush\\George_W_Bush_0277.jpg',
#  'George_W_Bush\\George_W_Bush_0281.jpg',
#  'George_W_Bush\\George_W_Bush_0282.jpg',
#  'George_W_Bush\\George_W_Bush_0290.jpg',
#  'George_W_Bush\\George_W_Bush_0291.jpg',
#  'George_W_Bush\\George_W_Bush_0293.jpg',
#  'George_W_Bush\\George_W_Bush_0296.jpg',
#  'George_W_Bush\\George_W_Bush_0299.jpg',
#  'George_W_Bush\\George_W_Bush_0302.jpg',
#  'George_W_Bush\\George_W_Bush_0312.jpg',
#  'George_W_Bush\\George_W_Bush_0314.jpg',
#  'George_W_Bush\\George_W_Bush_0315.jpg',
#  'George_W_Bush\\George_W_Bush_0321.jpg',
#  'George_W_Bush\\George_W_Bush_0324.jpg',
#  'George_W_Bush\\George_W_Bush_0330.jpg',
#  'George_W_Bush\\George_W_Bush_0332.jpg',
#  'George_W_Bush\\George_W_Bush_0335.jpg',
#  'George_W_Bush\\George_W_Bush_0338.jpg',
#  'George_W_Bush\\George_W_Bush_0339.jpg',
#  'George_W_Bush\\George_W_Bush_0341.jpg',
#  'George_W_Bush\\George_W_Bush_0348.jpg',
#  'George_W_Bush\\George_W_Bush_0349.jpg',
#  'George_W_Bush\\George_W_Bush_0351.jpg',
#  'George_W_Bush\\George_W_Bush_0355.jpg',
#  'George_W_Bush\\George_W_Bush_0358.jpg',
#  'George_W_Bush\\George_W_Bush_0359.jpg',
#  'George_W_Bush\\George_W_Bush_0361.jpg',
#  'George_W_Bush\\George_W_Bush_0362.jpg',
#  'George_W_Bush\\George_W_Bush_0363.jpg',
#  'George_W_Bush\\George_W_Bush_0364.jpg',
#  'George_W_Bush\\George_W_Bush_0366.jpg',
#  'George_W_Bush\\George_W_Bush_0367.jpg',
#  'George_W_Bush\\George_W_Bush_0370.jpg',
#  'George_W_Bush\\George_W_Bush_0374.jpg',
#  'George_W_Bush\\George_W_Bush_0376.jpg',
#  'George_W_Bush\\George_W_Bush_0379.jpg',
#  'George_W_Bush\\George_W_Bush_0380.jpg',
#  'George_W_Bush\\George_W_Bush_0381.jpg',
#  'George_W_Bush\\George_W_Bush_0382.jpg',
#  'George_W_Bush\\George_W_Bush_0390.jpg',
#  'George_W_Bush\\George_W_Bush_0392.jpg',
#  'George_W_Bush\\George_W_Bush_0398.jpg',
#  'George_W_Bush\\George_W_Bush_0401.jpg',
#  'George_W_Bush\\George_W_Bush_0402.jpg',
#  'George_W_Bush\\George_W_Bush_0403.jpg',
#  'George_W_Bush\\George_W_Bush_0404.jpg',
#  'George_W_Bush\\George_W_Bush_0413.jpg',
#  'George_W_Bush\\George_W_Bush_0417.jpg',
#  'George_W_Bush\\George_W_Bush_0418.jpg',
#  'George_W_Bush\\George_W_Bush_0420.jpg',
#  'George_W_Bush\\George_W_Bush_0422.jpg',
#  'George_W_Bush\\George_W_Bush_0427.jpg',
#  'George_W_Bush\\George_W_Bush_0428.jpg',
#  'George_W_Bush\\George_W_Bush_0429.jpg',
#  'George_W_Bush\\George_W_Bush_0432.jpg',
#  'George_W_Bush\\George_W_Bush_0436.jpg',
#  'George_W_Bush\\George_W_Bush_0437.jpg',
#  'George_W_Bush\\George_W_Bush_0440.jpg',
#  'George_W_Bush\\George_W_Bush_0441.jpg',
#  'George_W_Bush\\George_W_Bush_0442.jpg',
#  'George_W_Bush\\George_W_Bush_0444.jpg',
#  'George_W_Bush\\George_W_Bush_0445.jpg',
#  'George_W_Bush\\George_W_Bush_0447.jpg',
#  'George_W_Bush\\George_W_Bush_0448.jpg',
#  'George_W_Bush\\George_W_Bush_0449.jpg',
#  'George_W_Bush\\George_W_Bush_0452.jpg',
#  'George_W_Bush\\George_W_Bush_0461.jpg',
#  'George_W_Bush\\George_W_Bush_0464.jpg',
#  'George_W_Bush\\George_W_Bush_0465.jpg',
#  'George_W_Bush\\George_W_Bush_0466.jpg',
#  'George_W_Bush\\George_W_Bush_0467.jpg',
#  'George_W_Bush\\George_W_Bush_0471.jpg',
#  'George_W_Bush\\George_W_Bush_0472.jpg',
#  'George_W_Bush\\George_W_Bush_0473.jpg',
#  'George_W_Bush\\George_W_Bush_0474.jpg',
#  'George_W_Bush\\George_W_Bush_0475.jpg',
#  'George_W_Bush\\George_W_Bush_0479.jpg',
#  'George_W_Bush\\George_W_Bush_0480.jpg',
#  'George_W_Bush\\George_W_Bush_0486.jpg',
#  'George_W_Bush\\George_W_Bush_0488.jpg',
#  'George_W_Bush\\George_W_Bush_0491.jpg',
#  'George_W_Bush\\George_W_Bush_0494.jpg',
#  'George_W_Bush\\George_W_Bush_0496.jpg',
#  'George_W_Bush\\George_W_Bush_0498.jpg',
#  'George_W_Bush\\George_W_Bush_0504.jpg',
#  'George_W_Bush\\George_W_Bush_0508.jpg',
#  'George_W_Bush\\George_W_Bush_0515.jpg',
#  'George_W_Bush\\George_W_Bush_0516.jpg',
#  'George_W_Bush\\George_W_Bush_0520.jpg',
#  'George_W_Bush\\George_W_Bush_0524.jpg',
#  'George_W_Bush\\George_W_Bush_0527.jpg',
#  'George_W_Bush\\George_W_Bush_0529.jpg',
#  'George_W_Bush\\George_W_Bush_0530.jpg',
#  'not_George\\Abdullah_Gul_0004.jpg',
#  'not_George\\Alejandro_Avila_0003.jpg',
#  'not_George\\Aleksander_Kwasniewski_0001.jpg',
#  'not_George\\Alfredo_Pena_0001.jpg',
#  'not_George\\Alvaro_Silva_Calderon_0002.jpg',
#  'not_George\\Alvaro_Uribe_0035.jpg',
#  'not_George\\Anders_Ebbeson_0003.jpg',
#  'not_George\\Angela_Bassett_0002.jpg',
#  'not_George\\Anna_Kournikova_0009.jpg',
#  'not_George\\Ariel_Sharon_0076.jpg',
#  'not_George\\Arnold_Schwarzenegger_0010.jpg',
#  'not_George\\Arnold_Schwarzenegger_0014.jpg',
#  'not_George\\Arsinee_Khanjian_0002.jpg',
#  'not_George\\Atal_Bihari_Vajpayee_0003.jpg',
#  'not_George\\Betsy_Smith_0002.jpg',
#  'not_George\\Beyonce_Knowles_0001.jpg',
#  'not_George\\Bijan_Namdar_Zangeneh_0002.jpg',
#  'not_George\\Bill_Frist_0003.jpg',
#  'not_George\\Bill_Simon_0002.jpg',
#  'not_George\\Bill_Simon_0010.jpg',
#  'not_George\\Billy_Crystal_0003.jpg',
#  'not_George\\Bo_Pelini_0002.jpg',
#  'not_George\\Bob_Graham_0006.jpg',
#  'not_George\\Bob_Hayes_0001.jpg',
#  'not_George\\Bob_Hope_0003.jpg',
#  'not_George\\Bono_0002.jpg',
#  'not_George\\Brett_Hull_0001.jpg',
#  'not_George\\Candie_Kung_0004.jpg',
#  'not_George\\Carlos_Menem_0008.jpg',
#  'not_George\\Carlos_Moya_0019.jpg',
#  'not_George\\Carolina_Kluft_0003.jpg',
#  'not_George\\Carrie-Anne_Moss_0002.jpg',
#  'not_George\\Charlie_Williams_0001.jpg',
#  'not_George\\Chris_Gratton_0001.jpg',
#  'not_George\\Christopher_Reeve_0002.jpg',
#  'not_George\\Chung_Mong-joon_0002.jpg',
#  'not_George\\Clive_Lloyd_0001.jpg',
#  'not_George\\Cole_Chapman_0001.jpg',
#  'not_George\\Colin_Farrell_0006.jpg',
#  'not_George\\Colin_Farrell_0008.jpg',
#  'not_George\\Colin_Powell_0026.jpg',
#  'not_George\\Colin_Powell_0044.jpg',
#  'not_George\\Colin_Powell_0159.jpg',
#  'not_George\\Colin_Powell_0181.jpg',
#  'not_George\\Corinna_Harfouch_0001.jpg',
#  'not_George\\Crispin_Glover_0001.jpg',
#  'not_George\\Cruz_Bustamante_0003.jpg',
#  'not_George\\Dan_Guerrero_0001.jpg',
#  'not_George\\David_Stern_0001.jpg',
#  'not_George\\Dawn_Staley_0001.jpg',
#  'not_George\\Dean_Sheremet_0001.jpg',
#  'not_George\\Dennis_Miller_0001.jpg',
#  'not_George\\Dick_Cheney_0005.jpg',
#  'not_George\\Dick_Jauron_0001.jpg',
#  'not_George\\Dionyssis_Georgiadis_0001.jpg',
#  'not_George\\Dominique_de_Villepin_0001.jpg',
#  'not_George\\Dominique_de_Villepin_0010.jpg',
#  'not_George\\Donald_Rumsfeld_0068.jpg',
#  'not_George\\Donald_Rumsfeld_0101.jpg',
#  'not_George\\Donald_Rumsfeld_0110.jpg',
#  'not_George\\Dudley_Rogers_0001.jpg',
#  'not_George\\Dustin_Brown_0001.jpg',
#  'not_George\\Eduardo_Fischer_0001.jpg',
#  'not_George\\Edward_Lu_0004.jpg',
#  'not_George\\Elena_Bovina_0003.jpg',
#  'not_George\\Faye_Alibocus_0001.jpg',
#  'not_George\\Fernando_Leon_de_Aranoa_0001.jpg',
#  'not_George\\Francisco_Flores_0001.jpg',
#  'not_George\\Frank_Abagnale_Jr_0001.jpg',
#  'not_George\\Frank_Solich_0003.jpg',
#  'not_George\\Frank_Taylor_0001.jpg',
#  'not_George\\George_HW_Bush_0013.jpg',
#  'not_George\\Georgi_Parvanov_0002.jpg',
#  'not_George\\Gerhard_Schroeder_0017.jpg',
#  'not_George\\Gerhard_Schroeder_0027.jpg',
#  'not_George\\Gerhard_Schroeder_0098.jpg',
#  'not_George\\Gina_Lollobrigida_0001.jpg',
#  'not_George\\Gloria_Macapagal_Arroyo_0036.jpg',
#  'not_George\\Gonzalo_Sanchez_de_Lozada_0003.jpg',
#  'not_George\\Graeme_Smith_0001.jpg',
#  'not_George\\Gregg_Berhalter_0001.jpg',
#  'not_George\\Guillermo_Coria_0021.jpg',
#  'not_George\\Gunter_Pleuger_0007.jpg',
#  'not_George\\Gwyneth_Paltrow_0004.jpg',
#  'not_George\\Halle_Berry_0003.jpg',
#  'not_George\\Hamid_Karzai_0011.jpg',
#  'not_George\\Herb_Dhaliwal_0001.jpg',
#  'not_George\\Hillary_Clinton_0002.jpg',
#  'not_George\\Hilmi_Ozkok_0001.jpg',
#  'not_George\\Hisao_Oguchi_0001.jpg',
#  'not_George\\Horace_Newcomb_0001.jpg',
#  'not_George\\Howard_Schultz_0001.jpg',
#  'not_George\\Hu_Jintao_0011.jpg',
#  'not_George\\Hugo_Chavez_0049.jpg',
#  'not_George\\Ian_Smith_0001.jpg',
#  'not_George\\Ian_Thorpe_0009.jpg',
#  'not_George\\Inocencio_Arias_0002.jpg',
#  'not_George\\Isabelle_Huppert_0002.jpg',
#  'not_George\\Jack_Osbourne_0001.jpg',
#  'not_George\\Jackie_Chan_0006.jpg',
#  'not_George\\Jacques_Chirac_0038.jpg',
#  'not_George\\Jacques_Chirac_0039.jpg',
#  'not_George\\Jake_Gyllenhaal_0002.jpg',
#  'not_George\\James_Cameron_0002.jpg',
#  'not_George\\James_Maguire_0002.jpg',
#  'not_George\\James_Meredeth_0001.jpg',
#  'not_George\\Jean-Patrick_Nazon_0001.jpg',
#  'not_George\\Jean_Charest_0010.jpg',
#  'not_George\\Jean_Chretien_0031.jpg',
#  'not_George\\Jennifer_Capriati_0011.jpg',
#  'not_George\\Jennifer_Capriati_0029.jpg',
#  'not_George\\Jennifer_Garner_0003.jpg',
#  'not_George\\Jerry_Rice_0001.jpg',
#  'not_George\\Jesse_Harris_0002.jpg',
#  'not_George\\Jody_Richards_0001.jpg',
#  'not_George\\Joe_Lieberman_0001.jpg',
#  'not_George\\John_Ashcroft_0026.jpg',
#  'not_George\\John_Ashcroft_0046.jpg',
#  'not_George\\John_Howard_0006.jpg',
#  'not_George\\John_Mayer_0001.jpg',
#  'not_George\\John_Prescott_0001.jpg',
#  'not_George\\Jon_Kitna_0001.jpg',
#  'not_George\\Jose_Maria_Aznar_0004.jpg',
#  'not_George\\Joseph_Galante_0001.jpg',
#  'not_George\\Junichiro_Koizumi_0032.jpg',
#  'not_George\\Kelly_Leigh_0001.jpg',
#  'not_George\\Kelly_Osbourne_0001.jpg',
#  'not_George\\Kim_Jong-Il_0003.jpg',
#  'not_George\\Kofi_Annan_0020.jpg',
#  'not_George\\Kofi_Annan_0030.jpg',
#  'not_George\\Kurt_Russell_0001.jpg',
#  'not_George\\Lance_Armstrong_0007.jpg',
#  'not_George\\Lance_Armstrong_0014.jpg',
#  'not_George\\LeAnn_Rimes_0001.jpg',
#  'not_George\\Linda_Franklin_0001.jpg',
#  'not_George\\Lisa_Ling_0001.jpg',
#  'not_George\\Lleyton_Hewitt_0013.jpg',
#  'not_George\\Lleyton_Hewitt_0016.jpg',
#  'not_George\\Lleyton_Hewitt_0024.jpg',
#  'not_George\\Lucio_Gutierrez_0006.jpg',
#  'not_George\\Lucrecia_Orozco_0001.jpg',
#  'not_George\\Lucy_Liu_0003.jpg',
#  'not_George\\Lyudmila_Putin_0001.jpg',
#  'not_George\\Mahmoud_Abbas_0009.jpg',
#  'not_George\\Maria_Soledad_Alvear_Valenzuela_0002.jpg',
#  'not_George\\Mariah_Carey_0005.jpg',
#  'not_George\\Mario_Gallegos_0001.jpg',
#  'not_George\\Mark_Philippoussis_0010.jpg',
#  'not_George\\Melana_Scantlin_0001.jpg',
#  'not_George\\Michael_Phelps_0005.jpg',
#  'not_George\\Mickey_Rooney_0001.jpg',
#  'not_George\\Miguel_Estrada_0001.jpg',
#  'not_George\\Mike_Price_0002.jpg',
#  'not_George\\Mike_Stefanik_0001.jpg',
#  'not_George\\Miyako_Miyazaki_0001.jpg',
#  'not_George\\Mohammed_Dahlan_0001.jpg',
#  'not_George\\Muhammad_Ibrahim_Bilal_0001.jpg',
#  'not_George\\Neri_Marcore_0002.jpg',
#  'not_George\\Nestor_Kirchner_0025.jpg',
#  'not_George\\Nick_Nolte_0001.jpg',
#  'not_George\\Norah_Jones_0005.jpg',
#  'not_George\\Osama_bin_Laden_0003.jpg',
#  'not_George\\Patty_Schnyder_0001.jpg',
#  'not_George\\Paul_McCartney_0001.jpg',
#  'not_George\\Penny_Dupuie_0001.jpg',
#  'not_George\\Peter_Goldmark_0001.jpg',
#  'not_George\\Queen_Beatrix_0002.jpg',
#  'not_George\\Reinhard_Buetikofer_0001.jpg',
#  'not_George\\Rene_Portland_0001.jpg',
#  'not_George\\Ricardo_Lagos_0027.jpg',
#  'not_George\\Ricardo_Sanchez_0004.jpg',
#  'not_George\\Richard_Gere_0006.jpg',
#  'not_George\\Robert_Durst_0001.jpg',
#  'not_George\\Robert_Nardelli_0001.jpg',
#  'not_George\\Robert_Vowler_0001.jpg',
#  'not_George\\Rod_Bryden_0001.jpg',
#  'not_George\\Roh_Moo-hyun_0031.jpg',
#  'not_George\\Ronald_White_0001.jpg',
#  'not_George\\Scott_McClellan_0002.jpg',
#  'not_George\\Sergey_Lavrov_0004.jpg',
#  'not_George\\Sheila_Copps_0004.jpg',
#  'not_George\\Silvio_Berlusconi_0011.jpg',
#  'not_George\\Silvio_Berlusconi_0024.jpg',
#  'not_George\\Slobodan_Milosevic_0002.jpg',
#  'not_George\\Spike_Lee_0001.jpg',
#  'not_George\\Steffi_Graf_0005.jpg',
#  'not_George\\Stephen_Joseph_0001.jpg',
#  'not_George\\Steve_Blankenship_0001.jpg',
#  'not_George\\Suzanne_Gaudet_0001.jpg',
#  'not_George\\Teruaki_Masumoto_0001.jpg',
#  'not_George\\Thaksin_Shinawatra_0002.jpg',
#  'not_George\\Tim_Robbins_0004.jpg',
#  'not_George\\Tommy_Thompson_0005.jpg',
#  'not_George\\Tony_Blair_0049.jpg',
#  'not_George\\Tony_Blair_0056.jpg',
#  'not_George\\Tony_Blair_0116.jpg',
#  'not_George\\Tony_Parker_0001.jpg',
#  'not_George\\Venus_Williams_0002.jpg',
#  'not_George\\Vicente_Fox_0009.jpg',
#  'not_George\\Vidar_Helgesen_0001.jpg',
#  'not_George\\Vladimir_Putin_0029.jpg',
#  'not_George\\Wallace_Capel_0001.jpg',
#  'not_George\\Wayne_Newton_0001.jpg',
#  'not_George\\Wilson_Alvarez_0001.jpg',
#  'not_George\\Zico_0002.jpg',
#  'not_George\\Zinedine_Zidane_0006.jpg']

# %%
Bush_test_name_order[1]
# Out:
# 'George_W_Bush\\George_W_Bush_0003.jpg'

# %%
Bush_predictions_0 = predictions("working/Bush_test/not_George/", cnn_model, binary=True)
Bush_predictions_1 = predictions("working/Bush_test/George_W_Bush/", cnn_model, binary=True)

# Compare predictions to actual classes
Bush_predictions_frame = pd.DataFrame(
    list(zip(
        Bush_predictions_0 + Bush_predictions_1,
        [0] * len(Bush_predictions_0) + [1] * len(Bush_predictions_1)
    )),
    columns=['Predictions', 'Actual']
)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 723ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step

# %%
Bush_predictions_frame.sample(10)
# Out:
#      Predictions  Actual
# 387          0.0       1
# 308          1.0       1
# 217          1.0       1
# 370          1.0       1
# 41           0.0       0
# 273          0.0       1
# 117          0.0       0
# 174          0.0       0
# 170          0.0       0
# 13           0.0       0

# %%
# function for finding the precision and recall of predictions, for any number of predictive classes
def prec_acc(predictions_frame):
    precision = []
    accuracy = []
    recall = []
    for i in range(len(set(predictions_frame.Predictions))):
        tp = predictions_frame[np.logical_and(predictions_frame['Actual'] == i, predictions_frame['Predictions'] == i)].shape[0]
        tn = predictions_frame[np.logical_and(predictions_frame['Actual'] != i, predictions_frame['Predictions'] != i)].shape[0]
        fp = predictions_frame[np.logical_and(predictions_frame['Actual'] != i, predictions_frame['Predictions'] == i)].shape[0]
        fn = predictions_frame[np.logical_and(predictions_frame['Actual'] == i, predictions_frame['Predictions'] != i)].shape[0]
        total_preds = predictions_frame.shape[0]
        #precision.append(tp/(tp + fp))
        accuracy.append((tp + tn)/total_preds)
        #recall.append(tp/(tp + fn))
    #return(accuracy,precision,recall)
    return(accuracy)

# %%
Bush_accuracy = prec_acc(Bush_predictions_frame)
print('accuracy:' + str(Bush_accuracy[0]))
#print('Recall:' + str(Bush_accuracy[2]))
#print(Bush_test_name_order)
# Out:
# accuracy:0.8947368421052632
